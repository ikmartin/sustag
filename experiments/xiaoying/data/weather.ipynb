# %%
import pandas as pd

df = pd.read_csv("Iowa weather by region.csv", nrows=100)
print(df.head(100))
# Out:
#    station                           station_name        lat        lon  \
# 0   IAC009      Iowa - Southeast Climate Division  41.038704 -91.820563
# 1   IAC008  Iowa - South Central Climate Division  41.046732 -93.494076
# 2   IAC001      Iowa - Northwest Climate Division  43.027021 -95.494509
# 3   IAC006   Iowa - East Central Climate Division  41.897557 -91.253430
# 4   IAC002  Iowa - North Central Climate Division  43.049860 -93.489026
# ..     ...                                    ...        ...        ...
# 95  IAC005        Iowa - Central Climate Division  42.041101 -93.335289
# 96  IAC006   Iowa - East Central Climate Division  41.897557 -91.253430
# 97  IAC009      Iowa - Southeast Climate Division  41.038704 -91.820563
# 98  IAC007      Iowa - Southwest Climate Division  41.080948 -95.137948
# 99  IAC006   Iowa - East Central Climate Division  41.897557 -91.253430
#
#                  day  doy  high  low  precip  snow
# 0    1/1/00 12:00 AM    1    47   25     0.0   0.0
# ...
