# %% [markdown]
# Use this cell for evaluating the results of experiments

# %%
import pandas as pd

def make_markdown(df):
    lines = [[f"{col}" for col in df.columns], ["-" for col in df.columns]]
    lines += [[f"{value}" for value in df.iloc[i]] for i in range(df.shape[0])]
    lines = ["|" + "|".join(line) + "|" for line in lines]
    final = "\n".join(lines)
    return final

def keep_top_n_rows(df, n=15, score_cols=None, index_col="features"):
    """Keep rows in the top `n` of at least one score column. The `features`
    (string) column is moved to the index so it's preserved, then restored."""
    out = df.set_index(index_col) if index_col and index_col in df.columns else df

    if score_cols is None:
        num = out.select_dtypes("number")          # ranks on numeric cols only
        score_cols = [c for c in num.columns if not c.endswith("_pct")]

    keep = set()
    for c in score_cols:
        keep |= set(out[c].nlargest(n).index)

    out = out.loc[out.index.isin(keep)]
    return out.reset_index()                        # 'features' back as a column

n = 12
def print_tables(exp):
    filename = exp 
    res = pd.read_csv(filename + ".csv")
    imp1 = pd.read_csv(filename + "_importance.csv")
    #imp2 = pd.read_csv(filename + "_importance_perm.csv")
    imp1 = imp1.loc[:, ~(imp1.columns.str.startswith("Unnamed:") | imp1.columns.str.endswith("_pct"))]
    #imp2 = imp2.loc[:, ~(imp2.columns.str.startswith("Unnamed:") | imp2.columns.str.endswith("_pct"))]
    top1 = keep_top_n_rows(imp1, n=n)
    #top2 = keep_top_n_rows(imp2, n=n)
    print("\n#### Results")
    print(make_markdown(res))
    print(f"\n#### Exp {exp} Feature Importance XGBoost\n(Top {n} kept for each column)")
    print(make_markdown(top1))
    #print(f"\n#### Exp {exp} Feature Importance Col Shuffle\n(Top {n} kept for each column)")
    #print(make_markdown(top2))

# %%
exp = "16c"
filename = f"experiments/test_results/_experiment{exp}"
filename1 = f"models/recipe_CLF1.1"
print_tables(filename)
# Out:
# #### Results
# |recipe|n_sites|median_auc|mean_auc|
# |-|-|-|-|
# |spike_AR_clf_N=21|46|0.7397631906283951|0.7401550516328909|
# |spike_clf_N=21|46|0.6190276026061928|0.6243645021204337|
# |spike_AR_clf_N=30|46|0.775976789275681|0.7587858746281687|
# |spike_clf_N=30|46|0.6490704187884253|0.6394298477136169|
# |spike_AR_clf_N=45|46|0.779431181931706|0.7597100234770245|
# |spike_clf_N=45|46|0.639408705839082|0.6476148634549177|
# |spike_AR_clf_N=60|46|0.8001872785954953|0.7698047975225811|
# |spike_clf_N=60|46|0.6416462418300655|0.6513631501333187|
# |spike_AR_clf_N=90|46|0.7710352978640016|0.7394477477210543|
# |spike_clf_N=90|46|0.6838943281855929|0.6523299498880994|
#
# #### Exp experiments/test_results/_experiment16c Feature Importance XGBoost
# (Top 12 kept for each column)
# |features|spike_AR_clf_N=21|spike_clf_N=21|spike_AR_clf_N=30|spike_clf_N=30|spike_AR_clf_N=45|spike_clf_N=45|spike_AR_clf_N=60|spike_clf_N=60|spike_AR_clf_N=90|spike_clf_N=90|
    lines = ["|" + "|".join(line) + "|" for line in lines]
    final = "\n".join(lines)
    return final

a1 = pd.read_csv("experiments/test_results/_experiment15_all_sites_reg.csv")
a2 = pd.read_csv("experiments/test_results/_experiment15_group_2_sites_reg.csv")
a3 = pd.read_csv("experiments/test_results/_experiment15_non-group2_sites_reg.csv")
b1 = pd.read_csv("experiments/test_results/_experiment15_all_sites_clf.csv")
b2 = pd.read_csv("experiments/test_results/_experiment15_group_2_sites_clf.csv")
b3 = pd.read_csv("experiments/test_results/_experiment15_non-group2_sites_clf.csv")

csvs = [a1,a2,a3,b1,b2,b3]
for file in csvs:
    print(make_markdown(file))
# Out:
# |recipe|n_sites|n_families|n_rows|n_feat|loso_r2|lofo_r2|rmse|persist_skill|spearman|between_r2|within_r2|macro_r2|
# |-|-|-|-|-|-|-|-|-|-|-|-|-|
# |all_sites_reg|80|19|160074|50|0.3990824574730388|0.3228869259961437|4.28981768380006|-7.12744028931637|0.6612195645019543|0.2707830384615415|0.4186904272025866|0.2466304314137792|
# |recipe|n_sites|n_families|n_rows|n_feat|loso_r2|lofo_r2|rmse|persist_skill|spearman|between_r2|within_r2|macro_r2|
# |-|-|-|-|-|-|-|-|-|-|-|-|-|
# |group_2_sites_reg|18|1|43782|50|0.3254509416831548|nan|4.6117620300679105|-13.29737648631821|0.692052854047505|-0.0197224780726523|0.4101092448786044|0.2973334991829978|
# |recipe|n_sites|n_families|n_rows|n_feat|loso_r2|lofo_r2|rmse|persist_skill|spearman|between_r2|within_r2|macro_r2|
# |-|-|-|-|-|-|-|-|-|-|-|-|-|
# |non-group2_sites_reg|62|18|116292|50|0.3900214354605832|0.2787398921150429|4.296716210460551|-6.2025705914497635|0.6539493322416982|0.2182002260810961|0.3784114005299763|0.2500336702392144|
# |recipe|n_sites|n_families|n_rows|n_feat|loso_auc|lofo_auc|prauc|brier|persist_skill|base|between_rate_r2|macro_auc|
# |-|-|-|-|-|-|-|-|-|-|-|-|-|
# |all_sites_clf|80|19|160074|49|0.8376258022452489|0.8055432059174223|0.6833678695324898|0.1380234240949757|-3.994190064890996|0.2626847582992865|0.2262829320915895|0.9013995127202674|
# |recipe|n_sites|n_families|n_rows|n_feat|loso_auc|lofo_auc|prauc|brier|persist_skill|base|between_rate_r2|macro_auc|
# |-|-|-|-|-|-|-|-|-|-|-|-|-|
# |group_2_sites_clf|18|1|43782|49|0.8301074049350198|nan|0.7115668822627305|0.1519916156311719|-4.635245184446672|0.3104700561874743|-0.0370439259783326|0.9118162735661692|
# |recipe|n_sites|n_families|n_rows|n_feat|loso_auc|lofo_auc|prauc|brier|persist_skill|base|between_rate_r2|macro_auc|
# |-|-|-|-|-|-|-|-|-|-|-|-|-|
# |non-group2_sites_clf|62|18|116292|49|0.8428020603061039|0.7812463556145853|0.6407416737839202|0.1338173370800057|-3.800015468469315|0.2446943899838338|0.0859272081766618|0.8777655536608173|
