# %%
import pandas as pd
import sys
sys.path.insert(0, "../../")
from src.data.access import get_basin_graph, _PROC_AUX

graph = get_basin_graph()
print(graph)
# Out:
# DiGraph with 123 nodes and 256 edges

# %%
edges = pd.read_parquet(_PROC_AUX / "basin_containment_graph.parquet")
edges
# Out:
#              child         parent   parent_area
# 0    USGS-05412500  USGS-05420400  2.195016e+11
# 1    USGS-05418110  USGS-05418400  1.303091e+09
# 2    USGS-05418110  USGS-05418720  4.828656e+09
# 3    USGS-05418110  USGS-05420400  2.195016e+11
# 4    USGS-05418110        WQS0110  4.828656e+09
# ..             ...            ...           ...
# 251        WQS0123        WQS0064  2.009172e+09
# 252        WQS0124        WQS0043  2.297954e+09
# 253        WQS0126        WQS0023  6.091029e+09
# 254        WQS0126        WQS0069  3.320273e+09
# 255        WQS0126        WQS0119  4.095771e+09
#
# [256 rows x 3 columns]
